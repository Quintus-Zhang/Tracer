# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.interpolate import CubicSpline

# %%
N_W = 1001
start = 0
end = 3000000
expand_fac = 5

# %%
evenly_spaced_grid = np.linspace(0, 1, N_W)

# %%
expand_grid = start + (end - start)*evenly_spaced_grid**expand_fac

# %%
y = np.zeros(N_W)
plt.scatter(expand_grid[:30], y[:30])
plt.show()

# %%
plt.scatter(expand_grid[-30:], y[-30:])
plt.show()

# %%
plt.plot(np.diff(expand_grid)[:200], '*')
plt.show()

# %% [markdown]
# ## Graph of consumption function

# %% [markdown]
# ### Exanpding grid on W with expanding factor 2 & Evenly grid on C

# %%
base_path = '/Users/Quintus/Google Drive/Dynamic Programming/code'
c_func_fp = os.path.join(base_path, 'results', 'c_orig_2_grid_w.xlsx')
c_df = pd.read_excel(c_func_fp)

grid_w = np.arange(1, end)
for age in range(22, 66):
    spline = CubicSpline(c_df[str(100)], c_df[str(age)], bc_type='natural')
    c = spline(grid_w)
    plt.plot(grid_w, c)
plt.show()

# %%
base_path = '/Users/Quintus/Google Drive/Dynamic Programming/code'
c_func_fp = os.path.join(base_path, 'results', 'c_orig_2_grid_w.xlsx')
c_df = pd.read_excel(c_func_fp)

grid_w = np.arange(1, 1000000)

spline = CubicSpline(c_df[str(100)], c_df['22'], bc_type='natural')
c = spline(grid_w)
plt.plot(grid_w, c, color='r', label='Age 22')

spline = CubicSpline(c_df[str(100)], c_df['35'], bc_type='natural')
c = spline(grid_w)
plt.plot(grid_w, c, color='g', label='Age 35')

spline = CubicSpline(c_df[str(100)], c_df['65'], bc_type='natural')
c = spline(grid_w)
plt.plot(grid_w, c, color='b', label='Age 65')

spline = CubicSpline(c_df[str(100)], c_df['85'], bc_type='natural')
c = spline(grid_w)
plt.plot(grid_w, c, color='y', label='Age 85')

plt.xlabel('Cash-on-hand')
plt.ylabel('Consumption')
plt.legend()
plt.show()

# %% [markdown]
# ### Evenly grid on W and C

# %%
c_func_fp = os.path.join(base_path, 'results', 'c_orig_evenly_grid_cw.xlsx')
c_df = pd.read_excel(c_func_fp)

for age in range(22, 66):
    spline = CubicSpline(c_df[str(100)], c_df[str(age)], bc_type='natural')
    grid_w = np.arange(1, end)
    c = spline(grid_w)
    plt.plot(grid_w, c)
plt.xlabel('Cash-on-hand')
plt.ylabel('Consumption')
plt.title('Consumption Functions(Age 22~65) - Evenly Spacing Grid')
plt.show()

# %%
base_path = '/Users/Quintus/Google Drive/Dynamic Programming/code'
c_func_fp = os.path.join(base_path, 'results', 'c_orig_evenly_grid_cw.xlsx')
c_df = pd.read_excel(c_func_fp)

grid_w = np.arange(1, 1000000)

spline = CubicSpline(c_df[str(100)], c_df['22'], bc_type='natural')
c = spline(grid_w)
plt.plot(grid_w, c, color='r', label='Age 22')

spline = CubicSpline(c_df[str(100)], c_df['35'], bc_type='natural')
c = spline(grid_w)
plt.plot(grid_w, c, color='g', label='Age 35')

spline = CubicSpline(c_df[str(100)], c_df['65'], bc_type='natural')
c = spline(grid_w)
plt.plot(grid_w, c, color='b', label='Age 65')

spline = CubicSpline(c_df[str(100)], c_df['85'], bc_type='natural')
c = spline(grid_w)
plt.plot(grid_w, c, color='y', label='Age 85')

plt.xlabel('Cash-on-hand')
plt.ylabel('Consumption')
plt.title('Consumption Functions(Age 22,35,65,85) - Evenly Spacing Grid')
plt.legend()
plt.show()

# %% [markdown]
# ### Exanpding grid on W and C with expanding factor 2

# %%
base_path = '/Users/Quintus/Google Drive/Dynamic Programming/code'
c_func_fp = os.path.join(base_path, 'results', 'c_orig_2_grid_cw.xlsx')
c_df = pd.read_excel(c_func_fp)

grid_w = np.arange(1, end)
for age in range(22, 66):
    spline = CubicSpline(c_df[str(100)], c_df[str(age)], bc_type='natural')
    c = spline(grid_w)
    plt.plot(grid_w, c)
plt.xlabel('Cash-on-hand')
plt.ylabel('Consumption')
plt.title('Consumption Functions(Age 22~65) - Expanding Spacing Grid')

plt.show()

# %%
base_path = '/Users/Quintus/Google Drive/Dynamic Programming/code'
c_func_fp = os.path.join(base_path, 'results', 'c_orig_2_grid_cw.xlsx')
c_df = pd.read_excel(c_func_fp)

grid_w = np.arange(1, 3000000)

spline = CubicSpline(c_df[str(100)], c_df['22'], bc_type='natural')
c = spline(grid_w)
plt.plot(grid_w, c, color='r', label='Age 22')

spline = CubicSpline(c_df[str(100)], c_df['35'], bc_type='natural')
c = spline(grid_w)
plt.plot(grid_w, c, color='g', label='Age 35')

spline = CubicSpline(c_df[str(100)], c_df['50'], bc_type='natural')
c = spline(grid_w)
plt.plot(grid_w, c, color='darkgrey', label='Age 50')

spline = CubicSpline(c_df[str(100)], c_df['65'], bc_type='natural')
c = spline(grid_w)
plt.plot(grid_w, c, color='b', label='Age 65')

spline = CubicSpline(c_df[str(100)], c_df['85'], bc_type='natural')
c = spline(grid_w)
plt.plot(grid_w, c, color='y', label='Age 85')

plt.xlabel('Cash-on-hand')
plt.ylabel('Consumption')
plt.title('Consumption Functions(Age 22,35,50,65,85) - Expanding Spacing Grid')
plt.legend()
plt.show()

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.interpolate import CubicSpline

# %%
N_W = 1001
start = 0
end = 3000000
expand_fac = 5

# %%
evenly_spaced_grid = np.linspace(0, 1, N_W)

# %%
expand_grid = start + (end - start)*evenly_spaced_grid**expand_fac

# %%
y = np.zeros(N_W)
plt.scatter(expand_grid[:30], y[:30])
plt.scatter([0, 0.02, 0.04, 0.06], [0.001, 0.001, 0.001, 0.001])
plt.legend(['expanding grid', 'evenly grid'])
plt.show()

# %%
plt.scatter(expand_grid[-30:], y[-30:])
plt.show()

# %%
plt.plot(np.diff(expand_grid)[:200], '*')
plt.show()

# %% [markdown]
# ## Graph of consumption function

# %% [markdown]
# ### For Baseline Case

# %%
base_path = '/Users/Quintus/Google Drive/Dynamic Programming/code'
c_func_fp = os.path.join(base_path, 'results', 'c_orig_2_grid_w_15m_coll.xlsx')
c_df = pd.read_excel(c_func_fp)

end = 15000000/100
grid_w = np.arange(1, end, 100)
for age in range(22, 100):
    spline = CubicSpline(c_df[str(100)], c_df[str(age)], bc_type='natural')
    c = spline(grid_w)
    plt.plot(grid_w, c, label=str(age))
plt.xlabel('Cash-on-hand')
plt.ylabel('Consumption')
plt.title('Consumption Functions(Age 22~65) - Expanding Spacing Grid')
# plt.legend()
plt.show()

# %%
base_path = '/Users/Quintus/Google Drive/Dynamic Programming/code'
c_func_fp = os.path.join(base_path, 'results', 'c_orig_2_grid_w_15m_coll.xlsx')
c_df = pd.read_excel(c_func_fp)

grid_w = np.arange(1, end, 100)

spline = CubicSpline(c_df[str(100)], c_df['22'], bc_type='natural')
c = spline(grid_w)
plt.plot(grid_w, c, color='r', label='Age 22')

spline = CubicSpline(c_df[str(100)], c_df['35'], bc_type='natural')
c = spline(grid_w)
plt.plot(grid_w, c, color='g', label='Age 35')

spline = CubicSpline(c_df[str(100)], c_df['50'], bc_type='natural')
c = spline(grid_w)
plt.plot(grid_w, c, color='darkgrey', label='Age 50')

spline = CubicSpline(c_df[str(100)], c_df['65'], bc_type='natural')
c = spline(grid_w)
plt.plot(grid_w, c, color='b', label='Age 65')

spline = CubicSpline(c_df[str(100)], c_df['85'], bc_type='natural')
c = spline(grid_w)
plt.plot(grid_w, c, color='y', label='Age 85')

plt.xlabel('Cash-on-hand')
plt.ylabel('Consumption')
plt.title('Consumption Functions(Age 22,35,50,65,85) - Expanding Spacing Grid')
plt.legend()
plt.show()

# %% [markdown]
# ### For Standard File name

# %%
base_path = '/Users/Quintus/Google Drive/Dynamic Programming/code'
c_func_fp = os.path.join(base_path, 'results', 'Iteration_8.xlsx')
c_df = pd.read_excel(c_func_fp)

end = 15000000
grid_w = np.arange(1, end, 100)
for age in range(22, 66):
    spline = CubicSpline(c_df[str(100)], c_df[str(age)], bc_type='natural')
    c = spline(grid_w)
    plt.plot(grid_w, c, label=str(age))
plt.xlabel('Cash-on-hand')
plt.ylabel('Consumption')
plt.title('Consumption Functions(Age 22~65) - Expanding Spacing Grid')
# plt.legend()
plt.show()

# %%
grid_w = np.arange(1, end, 100)

spline = CubicSpline(c_df[str(100)], c_df['22'], bc_type='natural')
c = spline(grid_w)
plt.plot(grid_w, c, color='r', label='Age 22')

spline = CubicSpline(c_df[str(100)], c_df['35'], bc_type='natural')
c = spline(grid_w)
plt.plot(grid_w, c, color='g', label='Age 35')

spline = CubicSpline(c_df[str(100)], c_df['50'], bc_type='natural')
c = spline(grid_w)
plt.plot(grid_w, c, color='darkgrey', label='Age 50')

spline = CubicSpline(c_df[str(100)], c_df['65'], bc_type='natural')
c = spline(grid_w)
plt.plot(grid_w, c, color='b', label='Age 65')

spline = CubicSpline(c_df[str(100)], c_df['85'], bc_type='natural')
c = spline(grid_w)
plt.plot(grid_w, c, color='y', label='Age 85')

plt.xlabel('Cash-on-hand')
plt.ylabel('Consumption')
plt.title('Consumption Functions(Age 22,35,50,65,85) - Expanding Spacing Grid')
plt.legend()
plt.show()

# %%
c_df.describe()
# Out:
#                 100            99            98            97            96  \
# count  1.001000e+03  1.001000e+03  1.001000e+03  1.001000e+03  1.001000e+03
# mean   3.753751e+06  1.951902e+06  1.349767e+06  1.047237e+06  8.643536e+05
# std    4.260368e+06  2.206821e+06  1.520377e+06  1.175322e+06  9.666623e+05
# min    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    2.343760e+05  1.294537e+05  9.460977e+04  7.718782e+04  6.679716e+04
# 50%    1.875001e+06  9.812505e+05  6.825003e+05  5.325002e+05  4.418752e+05
# 75%    6.328126e+06  3.286407e+06  2.269688e+06  1.759219e+06  1.451250e+06
# max    1.500000e+07  7.775000e+06  5.360000e+06  4.145000e+06  3.410000e+06
#
#                  95            94            93            92            91  \
# count  1.001000e+03  1.001000e+03  1.001000e+03  1.001000e+03  1.001000e+03
# mean   7.411479e+05  6.519538e+05  5.841285e+05  5.306049e+05  4.871565e+05
# std    8.260013e+05  7.241173e+05  6.466026e+05  5.854451e+05  5.357909e+05
# min    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    5.992213e+04  5.492211e+04  5.125022e+04  4.828145e+04  4.593769e+04
# 50%    3.812502e+05  3.368752e+05  3.031251e+05  2.768751e+05  2.556251e+05
# 75%    1.242422e+06  1.090547e+06  9.766407e+05  8.859376e+05  8.121094e+05
# max    2.915000e+06  2.560000e+06  2.285000e+06  2.070000e+06  1.895000e+06
#
#            ...                   31             30             29  \
# count      ...          1001.000000    1001.000000    1001.000000
# mean       ...        138676.383551  137559.323456  136415.495213
# std        ...        116656.041176  115789.612240  114880.930287
# min        ...             1.000000       1.000000       1.000000
# 25%        ...         52031.468531   51718.967219   51328.340578
# 50%        ...         96199.942852   95571.185055   94942.427259
# 75%        ...        212195.842765  210937.519271  208828.144078
# max        ...        435000.000000  433696.304652  430000.000000
#
#                   28             27             26             25  \
# count    1001.000000    1001.000000    1001.000000    1001.000000
# mean   135257.129167  134091.584068  132856.469221  131593.287505
# std    114007.978612  113216.447023  112362.008565  111562.017865
# min         1.000000       1.000000       1.000000       1.000000
# 25%     50859.588609   50312.711313   49609.583359   48750.204750
# 50%     93809.925824   93188.668037   92427.396073   91324.894677
# 75%    206718.768885  205069.425075  203792.047012  202500.018500
# max    425000.000000  422455.096770  420000.000000  415000.000000
#
#                   24             23             22
# count    1001.000000    1001.000000    1001.000000
# mean   130325.785636  128980.457665  127602.455340
# std    110864.214991  110101.791843  109404.941345
# min         1.000000       1.000000       1.000000
# 25%     47656.450156   46484.570234   45000.189000
# 50%     90541.122684   89461.121316   88654.849295
# 75%    200390.643307  198281.268115  196171.892922
# max    412514.976846  410000.000000  405000.000000
#
# [8 rows x 79 columns]
